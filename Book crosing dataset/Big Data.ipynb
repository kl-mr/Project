# %% [markdown]
# # Bid Data Project

# %% [markdown]
# ## First, install the enviorment

# %%
# 1) First: install Java, Spark and and run a local Spark session by just running this on Google Colab:
# !apt update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null   # !apt-get --> install java
# !wget -q https://downloads.apache.org/spark/spark-3.2.3/spark-3.2.3-bin-hadoop3.2.tgz  # !wget  --> download file from url
# !tar xf spark-3.2.3-bin-hadoop3.2.tgz  # !tar --> like unzip 
# !pip install -q findspark  # !pip  --> instal a package, we cant import a library without installing it first, most libraries that we used were already installed
# This are INSTALLATION COMMANDS IN LINUX that we run in our collab space, it's similar to downloading programs an installing them on our computers
# installs Apache Spark 3.1.2, Java 8, and Findspark, a library that makes it easy for Python to find Spark




# 2) Second: set the locations where Spark and Java are installed to let know Colab where to find it.
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.2.3-bin-hadoop3.2"




# 3) Third: import spark libraries and use them
import findspark
findspark.init("spark-3.2.3-bin-hadoop3.2") # SPARK_HOME
from pyspark.sql import SparkSession
# Create the session - We need to remember to close it at the end
# The session is basically our connection to Spark layer in the Hadoop ecosystem
spark = SparkSession.builder.master("local[*]").getOrCreate()
from pyspark.sql import Row
from pyspark.sql import functions

# %%
# The session is basically our connection to Spark layer in the Hadoop ecosystem
spark = SparkSession.builder.appName('ops').getOrCreate()
spark = SparkSession.builder.appName('agg').getOrCreate()
from pyspark.sql.types import (StructField, IntegerType,StringType, StructType)
import pyspark.sql.functions

# %% [markdown]
# <br>
# <br>
# <hr class="dashed">
# <br>
# <br>

# %% [markdown]
# ## Establishing connection between "Colab" to "Google Drive"

# %%
# Code for connecting our google drive to this collab notebook
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/BDA Technion/Big Data Project"  # Check what files we have in the path
# Out:
# 'Big Data project.ipynb'   BX-Book-Ratings.csv	'countries names.csv'   Users
#  BigDataProject.ipynb	   BX-Books.csv		 Proj2.ipynb
#  Books			   BX-Users.csv		 Ratings

# %% [markdown]
# <br>
# <br>
# <hr class="dashed">
# <br>
# <br>

# %% [markdown]
# #Open and clean the Ratings CSV file

# %%
# Open the RATINGS CSV file
RATINGS_DF = spark.read.options(header='True', delimiter=';',quote="").csv("/content/drive/MyDrive/BDA Technion/Big Data Project/BX-Book-Ratings.csv")
RATINGS_DF.show()
# Out:
# +--------+--------------+------------------+
# |"User-ID|      ""ISBN""|""Book-Rating""",,|
# +--------+--------------+------------------+
# | "276725|""034545104X""|          ""0""",,|
# | "276726|""0155061224""|          ""5""",,|
# | "276727|""0446520802""|          ""0""",,|
# | "276729|""052165615X""|          ""3""",,|
# | "276729|""0521795028""|          ""6""",,|
# | "276733|""2080674722""|          ""0""",,|
# | "276736|""3257224281""|          ""8""",,|
# | "276737|""0600570967""|          ""6""",,|
# | "276744|""038550120X""|          ""7""",,|
# | "276745| ""342310538""|         ""10""",,|
# | "276746|""0425115801""|          ""0""",,|
# | "276746|""0449006522""|          ""0""",,|
# | "276746|""0553561618""|          ""0""",,|
# | "276746|""055356451X""|          ""0""",,|
# | "276746|""0786013990""|          ""0""",,|
# | "276746|""0786014512""|          ""0""",,|
# | "276747|""0060517794""|          ""9""",,|
# | "276747|""0451192001""|          ""0""",,|
# | "276747|""0609801279""|          ""0""",,|
# | "276747|""0671537458""|          ""9""",,|
# +--------+--------------+------------------+
# only showing top 20 rows

# %%
# RATINGS Data cleaning
from pyspark.sql.functions  import *
RATINGS_DF=RATINGS_DF.withColumn('User-ID', regexp_replace('"User-ID', '"', '')).withColumn('ISBN', regexp_replace('""ISBN""', '"', '')).withColumn('Book-Rating', regexp_replace('""Book-Rating""",,', '"|,', '').cast('int'))
RATINGS_DF=RATINGS_DF.drop(RATINGS_DF['"User-ID'])
RATINGS_DF=RATINGS_DF.drop(RATINGS_DF['""ISBN""'])
RATINGS_DF=RATINGS_DF.drop(RATINGS_DF['""Book-Rating""",,'])
RATINGS_DF=RATINGS_DF.withColumn('User-ID', RATINGS_DF['User-ID'].cast('int'))
RATINGS_DF.show()
# Out:
# +-------+----------+-----------+
# |User-ID|      ISBN|Book-Rating|
# +-------+----------+-----------+
# | 276725|034545104X|          0|
# | 276726|0155061224|          5|
# | 276727|0446520802|          0|
# | 276729|052165615X|          3|
# | 276729|0521795028|          6|
# | 276733|2080674722|          0|
# | 276736|3257224281|          8|
# | 276737|0600570967|          6|
# | 276744|038550120X|          7|
# | 276745| 342310538|         10|
# | 276746|0425115801|          0|
# | 276746|0449006522|          0|
# | 276746|0553561618|          0|
# | 276746|055356451X|          0|
# | 276746|0786013990|          0|
# | 276746|0786014512|          0|
# | 276747|0060517794|          9|
# | 276747|0451192001|          0|
# | 276747|0609801279|          0|
# | 276747|0671537458|          9|
# +-------+----------+-----------+
# only showing top 20 rows

# %%
RATINGS_DF.printSchema()
# Out:
# root
#  |-- User-ID: integer (nullable = true)
#  |-- ISBN: string (nullable = true)
#  |-- Book-Rating: integer (nullable = true)

# %%
#Check for Null Vaules

from pyspark.sql.functions import isnan, when, count, col

RATINGS_DF.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in RATINGS_DF.columns]).show()
# Out:
# +-------+----+-----------+
# |User-ID|ISBN|Book-Rating|
# +-------+----+-----------+
# |      0|   0|          0|
# +-------+----+-----------+

# %%
RATINGS_DF.groupBy("Book-Rating").count().orderBy(RATINGS_DF["Book-Rating"].asc()).show()
# Out:
# +-----------+------+
# |Book-Rating| count|
# +-----------+------+
# |          0|651330|
# |          1|  1601|
# |          2|  2492|
# |          3|  5445|
# |          4|  8031|
# |          5| 46953|
# |          6| 33753|
# |          7| 70018|
# |          8| 95037|
# |          9| 62101|
# |         10| 71814|
# +-----------+------+

# %%
#Check dublicates
RATINGS_DF_distinct= RATINGS_DF.distinct()
print("Distinct count: "+str(RATINGS_DF_distinct.count()))
print("ALL count: "+str(RATINGS_DF.count()))
# Out:
# Distinct count: 1048575
# ALL count: 1048575

# %%
#Check how many unique users and books exist
RATINGS_DF.select(countDistinct('ISBN')).show()
RATINGS_DF.select(countDistinct('User-ID')).show()
# Out:
# +--------------------+
# |count(DISTINCT ISBN)|
# +--------------------+
# |              323418|
# +--------------------+
#
# +-----------------------+
# |count(DISTINCT User-ID)|
# +-----------------------+
# |                  95513|
# +-----------------------+

# %%
#Save file in csv
RATINGS_DF.coalesce(1).write.option('header', 'True').csv("/content/drive/MyDrive/BDA Technion/Big Data Project/Ratings")

# %% [markdown]
# <br>
# <br>
# <hr class="dashed">
# <br>
# <br>

# %% [markdown]
# #Open and clean the Books CSV file

# %%
# Open the books details CSV file
BOOKS_DF = spark.read.options(header='True', delimiter=';').csv("/content/drive/MyDrive/BDA Technion/Big Data Project/BX-Books.csv")
BOOKS_DF.show()

# %%
# BOOKS Data cleaning
BOOKS_DF=BOOKS_DF.drop(BOOKS_DF['Image-URL-S'])
BOOKS_DF=BOOKS_DF.drop(BOOKS_DF['Image-URL-M'])
BOOKS_DF=BOOKS_DF.drop(BOOKS_DF['Image-URL-L'])
BOOKS_DF.show()
# Out:
# +----------+--------------------+--------------------+-------------------+--------------------+
# |      ISBN|          Book-Title|         Book-Author|Year-Of-Publication|           Publisher|
# +----------+--------------------+--------------------+-------------------+--------------------+
# |0195153448| Classical Mythology|  Mark P. O. Morford|               2002|Oxford University...|
# |0002005018|        Clara Callan|Richard Bruce Wright|               2001|HarperFlamingo Ca...|
# |0060973129|Decision in Normandy|        Carlo D'Este|               1991|     HarperPerennial|
# |0374157065|Flu: The Story of...|    Gina Bari Kolata|               1999|Farrar Straus Giroux|
# |0393045218|The Mummies of Ur...|     E. J. W. Barber|               1999|W. W. Norton &amp...|
# |0399135782|The Kitchen God's...|             Amy Tan|               1991|    Putnam Pub Group|
# |0425176428|What If?: The Wor...|       Robert Cowley|               2000|Berkley Publishin...|
# |0671870432|     PLEADING GUILTY|         Scott Turow|               1993|          Audioworks|
# |0679425608|Under the Black F...|     David Cordingly|               1996|        Random House|
# |074322678X|Where You'll Find...|         Ann Beattie|               2002|            Scribner|
# |0771074670|Nights Below Stat...|David Adams Richards|               1988|     Emblem Editions|
# |080652121X|Hitler's Secret B...|          Adam Lebor|               2000|       Citadel Press|
# |0887841740|  The Middle Stories|         Sheila Heti|               2004|House of Anansi P...|
# |1552041778|            Jane Doe|        R. J. Kaiser|               1999|          Mira Books|
# |1558746218|A Second Chicken ...|       Jack Canfield|               1998|Health Communicat...|
# |1567407781|The Witchfinder (...|   Loren D. Estleman|               1998|Brilliance Audio ...|
# |1575663937|More Cunning Than...|  Robert Hendrickson|               1999|Kensington Publis...|
# |1881320189|Goodbye to the Bu...|        Julia Oliver|               1994|      River City Pub|
# |0440234743|       The Testament|        John Grisham|               1999|                Dell|
# |0452264464|Beloved (Plume Co...|       Toni Morrison|               1994|               Plume|
# +----------+--------------------+--------------------+-------------------+--------------------+
# only showing top 20 rows

# %%
BOOKS_DF = BOOKS_DF.withColumn("Year-Of-Publication",col("Year-Of-Publication").cast("int"))
BOOKS_DF.printSchema()
BOOKS_DF.groupBy("Year-Of-Publication").count().orderBy(BOOKS_DF["Year-Of-Publication"].desc()).show()
# Out:
# root
#  |-- ISBN: string (nullable = true)
#  |-- Book-Title: string (nullable = true)
#  |-- Book-Author: string (nullable = true)
#  |-- Year-Of-Publication: integer (nullable = true)
#  |-- Publisher: string (nullable = true)
#
# +-------------------+-----+
# |Year-Of-Publication|count|
# +-------------------+-----+
# |               2050|    2|
# |               2038|    1|
# |               2037|    1|
# |               2030|    7|
# |               2026|    1|
# |               2024|    1|
# |               2021|    1|
# |               2020|    3|
# |               2012|    1|
# |               2011|    2|
# |               2010|    2|
# |               2008|    1|
# |               2006|    3|
# |               2005|   46|
# |               2004| 5839|
# |               2003|14359|
# |               2002|17628|
# |               2001|17360|
# |               2000|17235|
# |               1999|17432|
# +-------------------+-----+
# only showing top 20 rows

# %%
#It looks like that some of the books Year-Of-Publication is after 2022 😯 Lets fix this
BOOKS_DF = BOOKS_DF.withColumn("Year-Of-Publication", when(BOOKS_DF['Year-Of-Publication'] > 2021,-1).otherwise(BOOKS_DF['Year-Of-Publication']))
BOOKS_DF.groupBy("Year-Of-Publication").count().orderBy(BOOKS_DF["Year-Of-Publication"].desc()).show()
# Out:
# +-------------------+-----+
# |Year-Of-Publication|count|
# +-------------------+-----+
# |               2021|    1|
# |               2020|    3|
# |               2012|    1|
# |               2011|    2|
# |               2010|    2|
# |               2008|    1|
# |               2006|    3|
# |               2005|   46|
# |               2004| 5839|
# |               2003|14359|
# |               2002|17628|
# |               2001|17360|
# |               2000|17235|
# |               1999|17432|
# |               1998|15767|
# |               1997|14892|
# |               1996|14031|
# |               1995|13548|
# |               1994|11796|
# |               1993|10602|
# +-------------------+-----+
# only showing top 20 rows

# %%
#Check for Null Vaules

BOOKS_DF.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in BOOKS_DF.columns]).show()
# Out:
# +----+----------+-----------+-------------------+---------+
# |ISBN|Book-Title|Book-Author|Year-Of-Publication|Publisher|
# +----+----------+-----------+-------------------+---------+
# |   0|         0|          0|                  0|        0|
# +----+----------+-----------+-------------------+---------+

# %%
#Check dublicates
BOOKS_DF_distinct= BOOKS_DF.distinct()
print("Distinct count: "+str(BOOKS_DF_distinct.count()))
print("ALL count: "+str(BOOKS_DF.count()))
# Out:
# Distinct count: 271379
# ALL count: 271379

# %%
#It seems like some ISBN don't exist in a book table
RATINGS_DF.select(countDistinct('ISBN').alias('QTY in Rating DF')).show()
BOOKS_DF.select(countDistinct('ISBN').alias('QTY inBOOK DF')).show()
# Out:
# +----------------+
# |QTY in Rating DF|
# +----------------+
# |          323418|
# +----------------+
#
# +-------------+
# |QTY inBOOK DF|
# +-------------+
# |       271379|
# +-------------+

# %%
#We can fix this with anti join
Missing=RATINGS_DF.join(BOOKS_DF, [RATINGS_DF.ISBN == BOOKS_DF.ISBN], how='left_anti')
Missing.show()
# Out:
# +-------+-----------+-----------+
# |User-ID|       ISBN|Book-Rating|
# +-------+-----------+-----------+
# | 276875| 880781112X|          6|
# | 277087| 8471662531|          7|
# | 278418| 0590468502|          0|
# | 278418| 1566820413|          0|
# |    183|   19973/88|          6|
# |   2033| 0099428385|          8|
# |   2349| 3442089611|          0|
# |   2442| 887684760X|          0|
# |   2442| 8879830678|          5|
# |   2615| 0140258418|          7|
# |   2807| 8425336880|          8|
# |   3081| 9707100567|         10|
# |   3363| 0471530050|          0|
# |   3757| 8425336880|          6|
# |   3757| 8432703518|          8|
# |   3757| 8485224574|          7|
# |   4207|84955010301|          0|
# |   4571| 0143003011|          6|
# |   5350| 3404118278|          0|
# |   6703| 840132744X|          0|
# +-------+-----------+-----------+
# only showing top 20 rows

# %%
Missing=Missing.drop(Missing['User-ID'])
Missing=Missing.drop(Missing['Book-Rating'])
Missing=Missing.distinct()

# %%
Missing.count()
# Out:
# 65594

# %%
BOOKS_DF = BOOKS_DF.unionByName(Missing, allowMissingColumns=True)

# %%
#We can see that there are 65595 new ISBN in Book_DF without any information
BOOKS_DF.select(countDistinct('ISBN').alias('QTY inBOOK DF')).show()
BOOKS_DF.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in BOOKS_DF.columns]).show()
# Out:
# +-------------+
# |QTY inBOOK DF|
# +-------------+
# |       336973|
# +-------------+
#
# +----+----------+-----------+-------------------+---------+
# |ISBN|Book-Title|Book-Author|Year-Of-Publication|Publisher|
# +----+----------+-----------+-------------------+---------+
# |   0|     65594|      65594|              65594|    65594|
# +----+----------+-----------+-------------------+---------+

# %%
BOOKS_DF.show()
# Out:
# +----------+--------------------+--------------------+-------------------+--------------------+
# |      ISBN|          Book-Title|         Book-Author|Year-Of-Publication|           Publisher|
# +----------+--------------------+--------------------+-------------------+--------------------+
# |0195153448| Classical Mythology|  Mark P. O. Morford|               2002|Oxford University...|
# |0002005018|        Clara Callan|Richard Bruce Wright|               2001|HarperFlamingo Ca...|
# |0060973129|Decision in Normandy|        Carlo D'Este|               1991|     HarperPerennial|
# |0374157065|Flu: The Story of...|    Gina Bari Kolata|               1999|Farrar Straus Giroux|
# |0393045218|The Mummies of Ur...|     E. J. W. Barber|               1999|W. W. Norton &amp...|
# |0399135782|The Kitchen God's...|             Amy Tan|               1991|    Putnam Pub Group|
# |0425176428|What If?: The Wor...|       Robert Cowley|               2000|Berkley Publishin...|
# |0671870432|     PLEADING GUILTY|         Scott Turow|               1993|          Audioworks|
# |0679425608|Under the Black F...|     David Cordingly|               1996|        Random House|
# |074322678X|Where You'll Find...|         Ann Beattie|               2002|            Scribner|
# |0771074670|Nights Below Stat...|David Adams Richards|               1988|     Emblem Editions|
# |080652121X|Hitler's Secret B...|          Adam Lebor|               2000|       Citadel Press|
# |0887841740|  The Middle Stories|         Sheila Heti|               2004|House of Anansi P...|
# |1552041778|            Jane Doe|        R. J. Kaiser|               1999|          Mira Books|
# |1558746218|A Second Chicken ...|       Jack Canfield|               1998|Health Communicat...|
# |1567407781|The Witchfinder (...|   Loren D. Estleman|               1998|Brilliance Audio ...|
# |1575663937|More Cunning Than...|  Robert Hendrickson|               1999|Kensington Publis...|
# |1881320189|Goodbye to the Bu...|        Julia Oliver|               1994|      River City Pub|
# |0440234743|       The Testament|        John Grisham|               1999|                Dell|
# |0452264464|Beloved (Plume Co...|       Toni Morrison|               1994|               Plume|
# +----------+--------------------+--------------------+-------------------+--------------------+
# only showing top 20 rows

# %%
#Save file in csv
BOOKS_DF.coalesce(1).write.option('header', 'True').csv("/content/drive/MyDrive/BDA Technion/Big Data Project/Books")

# %% [markdown]
# <br>
# <br>
# <hr class="dashed">
# <br>
# <br>

# %% [markdown]
# #Open and clean the Users CSV file

# %%
# Open the users details CSV file
USERS_DF = spark.read.options(header='True', delimiter=';').csv("/content/drive/MyDrive/BDA Technion/Big Data Project/BX-Users.csv")
USERS_DF.show()
# Out:
# +-------+--------------------+----+
# |User-ID|            Location| Age|
# +-------+--------------------+----+
# |      1|  nyc, new york, usa|NULL|
# |      2|stockton, califor...|  18|
# |      3|moscow, yukon ter...|NULL|
# |      4|porto, v.n.gaia, ...|  17|
# |      5|farnborough, hant...|NULL|
# |      6|santa monica, cal...|  61|
# |      7| washington, dc, usa|NULL|
# |      8|timmins, ontario,...|NULL|
# |      9|germantown, tenne...|NULL|
# |     10|albacete, wiscons...|  26|
# |     11|melbourne, victor...|  14|
# |     12|fort bragg, calif...|NULL|
# |     13|barcelona, barcel...|  26|
# |     14|mediapolis, iowa,...|NULL|
# |     15|calgary, alberta,...|NULL|
# |     16|albuquerque, new ...|NULL|
# |     17|chesapeake, virgi...|NULL|
# |     18|rio de janeiro, r...|  25|
# |     19|           weston, ,|  14|
# |     20|langhorne, pennsy...|  19|
# +-------+--------------------+----+
# only showing top 20 rows

# %%
#Split the location into 3 column
USERS_DF = USERS_DF.withColumn('City', split(USERS_DF['Location'], ',').getItem(0)) \
       .withColumn('State', split(USERS_DF['Location'], ',').getItem(1)) \
       .withColumn('Country', split(USERS_DF['Location'], ',').getItem(2))
USERS_DF=USERS_DF.drop(USERS_DF['Location']) 
USERS_DF = USERS_DF.withColumn("Country", lower(col("Country"))) 
USERS_DF = USERS_DF.withColumn('User-ID', USERS_DF['User-ID'].cast('int'))
USERS_DF = USERS_DF.withColumn('Age', USERS_DF.Age.cast('int'))
USERS_DF.show()
# Out:
# +-------+----+--------------+----------------+---------------+
# |User-ID| Age|          City|           State|        Country|
# +-------+----+--------------+----------------+---------------+
# |      1|null|           nyc|        new york|            usa|
# |      2|  18|      stockton|      california|            usa|
# |      3|null|        moscow| yukon territory|         russia|
# |      4|  17|         porto|        v.n.gaia|       portugal|
# |      5|null|   farnborough|           hants| united kingdom|
# |      6|  61|  santa monica|      california|            usa|
# |      7|null|    washington|              dc|            usa|
# |      8|null|       timmins|         ontario|         canada|
# |      9|null|    germantown|       tennessee|            usa|
# |     10|  26|      albacete|       wisconsin|          spain|
# |     11|  14|     melbourne|        victoria|      australia|
# |     12|null|    fort bragg|      california|            usa|
# |     13|  26|     barcelona|       barcelona|          spain|
# |     14|null|    mediapolis|            iowa|            usa|
# |     15|null|       calgary|         alberta|         canada|
# |     16|null|   albuquerque|      new mexico|            usa|
# |     17|null|    chesapeake|        virginia|            usa|
# |     18|  25|rio de janeiro|  rio de janeiro|         brazil|
# |     19|  14|        weston|                |               |
# |     20|  19|     langhorne|    pennsylvania|            usa|
# +-------+----+--------------+----------------+---------------+
# only showing top 20 rows

# %%
#There are no dublicates
USERS_DF_distinct= USERS_DF.distinct()
print("Distinct count: "+str(USERS_DF_distinct.count()))
print("ALL count: "+str(USERS_DF.count()))
# Out:
# Distinct count: 278859
# ALL count: 278859

# %%
#Check for Null Vaules
from pyspark.sql.functions import isnan, when, count, col
USERS_DF.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in USERS_DF.columns]).show()
# Out:
# +-------+------+----+-----+-------+
# |User-ID|   Age|City|State|Country|
# +-------+------+----+-----+-------+
# |      1|110763|   0|    3|      4|
# +-------+------+----+-----+-------+

# %%
#Data preparation
USERS_DF=USERS_DF.select([when(col(c)=="",None).otherwise(col(c)).alias(c) for c in USERS_DF.columns])

# %%
USERS_DF = USERS_DF.withColumn("State", when(USERS_DF['State'].endswith(' '),regexp_replace(USERS_DF['State'], ' ','unknown')).otherwise(USERS_DF['State']))
USERS_DF = USERS_DF.withColumn("Country", when(USERS_DF['Country'].endswith(' '),regexp_replace(USERS_DF['Country'], ' ','unknown')).otherwise(USERS_DF['Country']))
USERS_DF = USERS_DF.withColumn("City", when(USERS_DF['City'].endswith(' '),regexp_replace(USERS_DF['City'], ' ','unknown')).otherwise(USERS_DF['City']))

# %%
USERS_DF = USERS_DF.withColumn("State", when(USERS_DF['State'].endswith('n/a'),regexp_replace(USERS_DF['State'], 'n/a','unknown')).otherwise(USERS_DF['State']))
USERS_DF = USERS_DF.withColumn("Country", when(USERS_DF['Country'].endswith('n/a'),regexp_replace(USERS_DF['Country'], 'n/a','unknown')).otherwise(USERS_DF['Country']))
USERS_DF = USERS_DF.withColumn("City", when(USERS_DF['City'].endswith('n/a'),regexp_replace(USERS_DF['City'], 'n/a','unknown')).otherwise(USERS_DF['City']))

# %%
USERS_DF=USERS_DF.na.fill(value='unknown',subset=["Country"])
USERS_DF=USERS_DF.na.fill(value='unknown',subset=["State"])
USERS_DF=USERS_DF.na.fill(value='unknown',subset=["City"])

# %%
USERS_DF.show(20)
# Out:
# +-------+----+--------------+----------------+---------------+
# |User-ID| Age|          City|           State|        Country|
# +-------+----+--------------+----------------+---------------+
# |      1|null|           nyc|        new york|            usa|
# |      2|  18|      stockton|      california|            usa|
# |      3|null|        moscow| yukon territory|         russia|
# |      4|  17|         porto|        v.n.gaia|       portugal|
# |      5|null|   farnborough|           hants| united kingdom|
# |      6|  61|  santa monica|      california|            usa|
# |      7|null|    washington|              dc|            usa|
# |      8|null|       timmins|         ontario|         canada|
# |      9|null|    germantown|       tennessee|            usa|
# |     10|  26|      albacete|       wisconsin|          spain|
# |     11|  14|     melbourne|        victoria|      australia|
# |     12|null|    fort bragg|      california|            usa|
# |     13|  26|     barcelona|       barcelona|          spain|
# |     14|null|    mediapolis|            iowa|            usa|
# |     15|null|       calgary|         alberta|         canada|
# |     16|null|   albuquerque|      new mexico|            usa|
# |     17|null|    chesapeake|        virginia|            usa|
# |     18|  25|rio de janeiro|  rio de janeiro|         brazil|
# |     19|  14|        weston|         unknown|        unknown|
# |     20|  19|     langhorne|    pennsylvania|            usa|
# +-------+----+--------------+----------------+---------------+
# only showing top 20 rows

# %%
USERS_DF.printSchema()
USERS_DF.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in USERS_DF.columns]).show()
# Out:
# root
#  |-- User-ID: integer (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- City: string (nullable = false)
#  |-- State: string (nullable = false)
#  |-- Country: string (nullable = false)
#
# +-------+------+----+-----+-------+
# |User-ID|   Age|City|State|Country|
# +-------+------+----+-----+-------+
# |      1|110763|   0|    0|      0|
# +-------+------+----+-----+-------+

# %%
#We can see a lot of Age NULL VALUES! Lets fix this
USERS_DF=USERS_DF.na.fill(value=-1,subset=["Age"])
USERS_DF.show()
# Out:
# +-------+---+--------------+----------------+---------------+
# |User-ID|Age|          City|           State|        Country|
# +-------+---+--------------+----------------+---------------+
# |      1| -1|           nyc|        new york|            usa|
# |      2| 18|      stockton|      california|            usa|
# |      3| -1|        moscow| yukon territory|         russia|
# |      4| 17|         porto|        v.n.gaia|       portugal|
# |      5| -1|   farnborough|           hants| united kingdom|
# |      6| 61|  santa monica|      california|            usa|
# |      7| -1|    washington|              dc|            usa|
# |      8| -1|       timmins|         ontario|         canada|
# |      9| -1|    germantown|       tennessee|            usa|
# |     10| 26|      albacete|       wisconsin|          spain|
# |     11| 14|     melbourne|        victoria|      australia|
# |     12| -1|    fort bragg|      california|            usa|
# |     13| 26|     barcelona|       barcelona|          spain|
# |     14| -1|    mediapolis|            iowa|            usa|
# |     15| -1|       calgary|         alberta|         canada|
# |     16| -1|   albuquerque|      new mexico|            usa|
# |     17| -1|    chesapeake|        virginia|            usa|
# |     18| 25|rio de janeiro|  rio de janeiro|         brazil|
# |     19| 14|        weston|         unknown|        unknown|
# |     20| 19|     langhorne|    pennsylvania|            usa|
# +-------+---+--------------+----------------+---------------+
# only showing top 20 rows

# %%
UsersGroup = USERS_DF.groupBy("Age").count()
UsersGroup.orderBy(UsersGroup["Age"].desc()).show(10)
UsersGroup.orderBy(UsersGroup["Age"].asc()).show(10)
# Out:
# +---+-----+
# |Age|count|
# +---+-----+
# |244|    1|
# |239|    1|
# |237|    1|
# |231|    1|
# |230|    1|
# |229|    1|
# |228|    3|
# |226|    1|
# |223|    1|
# |220|    1|
# +---+-----+
# only showing top 10 rows
#
# +---+------+
# |Age| count|
# +---+------+
# | -1|110763|
# |  0|   416|
# |  1|   288|
# |  2|   105|
# |  3|    45|
# |  4|    28|
# |  5|    26|
# |  6|    18|
# |  7|    27|
# |  8|    54|
# +---+------+
# only showing top 10 rows

# %%
# Let's fix age less then 7 and more then 100
USERS_DF = USERS_DF.withColumn("Age", when(USERS_DF['Age'] > 100,-1) 
      .when(USERS_DF['Age'] < 7,-1) \
      .otherwise(USERS_DF['Age']))
UsersGroup = USERS_DF.groupBy("Age").count()
UsersGroup.orderBy(UsersGroup["Age"].desc()).show(10)
UsersGroup.orderBy(UsersGroup["Age"].asc()).show(10)
# Out:
# +---+-----+
# |Age|count|
# +---+-----+
# |100|    7|
# | 99|    4|
# | 98|    2|
# | 97|    3|
# | 96|    3|
# | 95|    1|
# | 94|    5|
# | 93|   15|
# | 92|   11|
# | 91|   13|
# +---+-----+
# only showing top 10 rows
#
# +---+------+
# |Age| count|
# +---+------+
# | -1|112055|
# |  7|    27|
# |  8|    54|
# |  9|    62|
# | 10|    84|
# | 11|   121|
# | 12|   192|
# | 13|   885|
# | 14|  1962|
# | 15|  2383|
# +---+------+
# only showing top 10 rows

# %%
#Cleaning of NULL value UsersID
USERS_DF.filter(col('User-ID').isNull()).show()
USERS_DF=USERS_DF.na.drop(subset=["User-ID"]) 
USERS_DF.filter(col('User-ID').isNull()).show()
# Out:
# +-------+---+----+-------+-------+
# |User-ID|Age|City|  State|Country|
# +-------+---+----+-------+-------+
# |   null| -1|NULL|unknown|unknown|
# +-------+---+----+-------+-------+
#
# +-------+---+----+-----+-------+
# |User-ID|Age|City|State|Country|
# +-------+---+----+-----+-------+
# +-------+---+----+-----+-------+

# %%
#There aren't Null values in the DataFrame anymore
USERS_DF.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in USERS_DF.columns]).show()
USERS_DF.count()
# Out:
# +-------+---+----+-----+-------+
# |User-ID|Age|City|State|Country|
# +-------+---+----+-----+-------+
# |      0|  0|   0|    0|      0|
# +-------+---+----+-----+-------+
# 278858

# %%
pip install pycountry
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 40.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from pycountry) (57.4.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=722f3c21ab50c0b211c8c79a5ace6b3e745fe3202d78611026bedf127ab33e8e
#   Stored in directory: /root/.cache/pip/wheels/e2/aa/0f/c224e473b464387170b83ca7c66947b4a7e33e8d903a679748
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
import pycountry
pycountry.countries.search_fuzzy('italy')
# Out:
# [Country(alpha_2='IT', alpha_3='ITA', flag='🇮🇹', name='Italy', numeric='380', official_name='Italian Republic')]

# %%
pycountry.countries.search_fuzzy('london')
# Out:
# [Country(alpha_2='GB', alpha_3='GBR', flag='🇬🇧', name='United Kingdom', numeric='826', official_name='United Kingdom of Great Britain and Northern Ireland')]

# %%
def convert(location):   # define function here
  try:
    if location:
      lc=pycountry.countries.search_fuzzy(location)
      return lc[0].alpha_3
    else: 
      return None
  except LookupError:
    return None  

cc_udf = udf(convert, StringType()) #register udf

# %%
#Create new table that is grouped by countries and ordered by count
UsersCountryGroup = USERS_DF.groupBy("Country").count()
UsersCountryGroup=UsersCountryGroup.orderBy(UsersCountryGroup["count"].desc())
UsersCountryGroup.show(20)
# Out:
# +---------------+------+
# |        Country| count|
# +---------------+------+
# |            usa|139188|
# |         canada| 21558|
# | united kingdom| 18304|
# |        germany| 17052|
# |          spain| 13205|
# |      australia| 11724|
# |          italy| 11246|
# |        unknown|  4625|
# |         france|  3474|
# |       portugal|  3371|
# |    new zealand|  3094|
# |    netherlands|  3043|
# |    switzerland|  1757|
# |         brazil|  1677|
# |          china|  1464|
# |         sweden|  1452|
# |          india|  1279|
# |        austria|  1147|
# |       malaysia|  1102|
# |      argentina|  1081|
# +---------------+------+
# only showing top 20 rows

# %%
#Let's use function to find country code
UsersCountryGroup = UsersCountryGroup.withColumn("countries_formatted",cc_udf(UsersCountryGroup.Country))
UsersCountryGroup.show(20)
# Out:
# +---------------+------+-------------------+
# |        Country| count|countries_formatted|
# +---------------+------+-------------------+
# |            usa|139188|                USA|
# |         canada| 21558|                CAN|
# | united kingdom| 18304|                GBR|
# |        germany| 17052|                DEU|
# |          spain| 13205|                ESP|
# |      australia| 11724|                AUS|
# |          italy| 11246|                ITA|
# |        unknown|  4625|               null|
# |         france|  3474|                FRA|
# |       portugal|  3371|                PRT|
# |    new zealand|  3094|                NZL|
# |    netherlands|  3043|                NLD|
# |    switzerland|  1757|                CHE|
# |         brazil|  1677|                BRA|
# |          china|  1464|                CHN|
# |         sweden|  1452|                SWE|
# |          india|  1279|                IND|
# |        austria|  1147|                AUT|
# |       malaysia|  1102|                MYS|
# |      argentina|  1081|                ARG|
# +---------------+------+-------------------+
# only showing top 20 rows

# %%
#Rename column to make a join
UsersCountryGroup =UsersCountryGroup.withColumnRenamed("Country","Distinct_Country")
UsersCountryGroup.show()
# Out:
# +----------------+------+-------------------+
# |Distinct_Country| count|countries_formatted|
# +----------------+------+-------------------+
# |             usa|139188|                USA|
# |          canada| 21558|                CAN|
# |  united kingdom| 18304|                GBR|
# |         germany| 17052|                DEU|
# |           spain| 13205|                ESP|
# |       australia| 11724|                AUS|
# |           italy| 11246|                ITA|
# |         unknown|  4625|               null|
# |          france|  3474|                FRA|
# |        portugal|  3371|                PRT|
# |     new zealand|  3094|                NZL|
# |     netherlands|  3043|                NLD|
# |     switzerland|  1757|                CHE|
# |          brazil|  1677|                BRA|
# |           china|  1464|                CHN|
# |          sweden|  1452|                SWE|
# |           india|  1279|                IND|
# |         austria|  1147|                AUT|
# |        malaysia|  1102|                MYS|
# |       argentina|  1081|                ARG|
# +----------------+------+-------------------+
# only showing top 20 rows

# %%
#Join new table with our Users_DF
USERS_DF=USERS_DF.join(UsersCountryGroup, USERS_DF["Country"] == UsersCountryGroup["Distinct_Country"],"left")
USERS_DF.show(20)
# Out:
# +-------+---+--------------+----------------+---------------+----------------+------+-------------------+
# |User-ID|Age|          City|           State|        Country|Distinct_Country| count|countries_formatted|
# +-------+---+--------------+----------------+---------------+----------------+------+-------------------+
# |      1| -1|           nyc|        new york|            usa|             usa|139188|                USA|
# |      2| 18|      stockton|      california|            usa|             usa|139188|                USA|
# |      3| -1|        moscow| yukon territory|         russia|          russia|   177|                RUS|
# |      4| 17|         porto|        v.n.gaia|       portugal|        portugal|  3371|                PRT|
# |      5| -1|   farnborough|           hants| united kingdom|  united kingdom| 18304|                GBR|
# |      6| 61|  santa monica|      california|            usa|             usa|139188|                USA|
# |      7| -1|    washington|              dc|            usa|             usa|139188|                USA|
# |      8| -1|       timmins|         ontario|         canada|          canada| 21558|                CAN|
# |      9| -1|    germantown|       tennessee|            usa|             usa|139188|                USA|
# |     10| 26|      albacete|       wisconsin|          spain|           spain| 13205|                ESP|
# |     11| 14|     melbourne|        victoria|      australia|       australia| 11724|                AUS|
# |     12| -1|    fort bragg|      california|            usa|             usa|139188|                USA|
# |     13| 26|     barcelona|       barcelona|          spain|           spain| 13205|                ESP|
# |     14| -1|    mediapolis|            iowa|            usa|             usa|139188|                USA|
# |     15| -1|       calgary|         alberta|         canada|          canada| 21558|                CAN|
# |     16| -1|   albuquerque|      new mexico|            usa|             usa|139188|                USA|
# |     17| -1|    chesapeake|        virginia|            usa|             usa|139188|                USA|
# |     18| 25|rio de janeiro|  rio de janeiro|         brazil|          brazil|  1677|                BRA|
# |     19| 14|        weston|         unknown|        unknown|         unknown|  4625|               null|
# |     20| 19|     langhorne|    pennsylvania|            usa|             usa|139188|                USA|
# +-------+---+--------------+----------------+---------------+----------------+------+-------------------+
# only showing top 20 rows

# %%
#Cleaning table from columns duplicates
USERS_DF=USERS_DF.drop(USERS_DF['Distinct_Country']) 
USERS_DF=USERS_DF.drop(USERS_DF['count'])

# %%
#Creating another table with rows where we couldn't identify country 
Users_NULL_Countries=USERS_DF.where(col("countries_formatted").isNull())
Users_NULL_Countries=Users_NULL_Countries.drop(Users_NULL_Countries['countries_formatted']) 
#This time we group new table by City values
Users_by_city=Users_NULL_Countries.groupBy("City").count() 
Users_by_city=Users_by_city.orderBy(Users_by_city["count"].desc())
Users_by_city.show()
# Out:
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "spark-3.2.3-bin-hadoop3.2/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "spark-3.2.3-bin-hadoop3.2/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-9d5f752424f3> in <module>
#       5 Users_by_city=Users_NULL_Countries.groupBy("City").count()
#       6 Users_by_city=Users_by_city.orderBy(Users_by_city["count"].desc())
# ----> 7 Users_by_city.show()
#
# /content/spark-3.2.3-bin-hadoop3.2/python/pyspark/sql/dataframe.py in show(self, n, truncate, vertical)
#     492
#     493         if isinstance(truncate, bool) and truncate:
# --> 494             print(self._jdf.showString(n, 20, vertical))
#     495         else:
#     496             try:
#
# spark-3.2.3-bin-hadoop3.2/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1318             proto.END_COMMAND_PART
#    1319
# -> 1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#
# spark-3.2.3-bin-hadoop3.2/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# spark-3.2.3-bin-hadoop3.2/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py in send_command(self, command)
#     509         try:
#     510             while True:
# --> 511                 answer = smart_decode(self.stream.readline()[:-1])
#     512                 logger.debug("Answer received: {0}".format(answer))
#     513                 # Happens when a the other end is dead. There might be an empty
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#Let's use function to find country code by City name
Users_by_city= Users_by_city.withColumn("countries_formatted_1",cc_udf(Users_by_city.City))
Users_by_city.show()
# Out:
# +------------+-----+-------------------+
# |        City|count|countries_formatted|
# +------------+-----+-------------------+
# |     unknown|  100|               null|
# |     toronto|   59|               null|
# |      milano|   59|                ITA|
# |   vancouver|   58|               null|
# |      london|   51|                GBR|
# |    belgrade|   50|               null|
# |        roma|   48|                ITA|
# |    portland|   45|                JAM|
# |     seattle|   38|               null|
# |      ottawa|   37|               null|
# |   barcelona|   33|                ESP|
# |        rome|   32|                CZE|
# |   san diego|   29|               null|
# |christchurch|   29|                GBR|
# |     chicago|   27|               null|
# |     houston|   27|               null|
# | albuquerque|   26|               null|
# |      austin|   25|               null|
# |      madrid|   25|                ESP|
# |    novi sad|   24|               null|
# +------------+-----+-------------------+
# only showing top 20 rows

# %%
Users_by_city.filter(Users_by_city.countries_formatted.isNull()).show()

# %%
Users_by_city=Users_by_city.withColumn("countries_formatted", when(Users_by_city['City'].endswith('toronto'),'CAN')
.when(Users_by_city['City'].endswith('vancouver'),'CAN')
.when(Users_by_city['City'].endswith('ottawa'),'CAN')
.when(Users_by_city['City'].endswith('belgrade'),'SRB')
.when(Users_by_city['City'].endswith('seattle'),'USA')
.when(Users_by_city['City'].endswith('rome'),'ITA')
.when(Users_by_city['City'].endswith('san diego'),'USA')
.when(Users_by_city['City'].endswith('chicago'),'USA')
.when(Users_by_city['City'].endswith('houston'),'USA')
.when(Users_by_city['City'].endswith('albuquerque'),'USA')
.when(Users_by_city['City'].endswith('austin'),'USA')
.when(Users_by_city['City'].endswith('novi sad'),'SRB')
.when(Users_by_city['City'].endswith('calgary'),'CAN')
.when(Users_by_city['City'].endswith('los angeles'),'USA')
.when(Users_by_city['City'].endswith('sydney'),'AUS')
.when(Users_by_city['City'].endswith('melbourne'),'AUS')
.when(Users_by_city['City'].endswith('cincinnati'),'USA')
.when(Users_by_city['City'].endswith('stuttgart'),'DEU')
.when(Users_by_city['City'].endswith('san francisco'),'USA')
.when(Users_by_city['City'].endswith('st. louis'),'USA')
.when(Users_by_city['City'].endswith('fredericton'),'CAN')
.when(Users_by_city['City'].endswith('raleigh'),'USA')
.when(Users_by_city['City'].endswith('oakland'),'USA')
.when(Users_by_city['City'].endswith('winnipeg'),'CAN')
.when(Users_by_city['City'].endswith('edmonton'),'CAN')
.when(Users_by_city['City'].endswith('tucson'),'USA')
.when(Users_by_city['City'].endswith('cairo'),'EGY')
.when(Users_by_city['City'].endswith('newark'),'USA')
.when(Users_by_city['City'].endswith('amsterdam'),'NLD')
.when(Users_by_city['City'].endswith('dubai'),'ARE')
.when(Users_by_city['City'].endswith('minneapolis'),'USA')
.when(Users_by_city['City'].endswith('copenhagen'),'DNA')
.when(Users_by_city['City'].endswith('hamilton'),'CAN')
.when(Users_by_city['City'].endswith('harrisburg'),'USA')
.when(Users_by_city['City'].endswith('davis'),'USA')
.when(Users_by_city['City'].endswith('bailey'),'USA')
.when(Users_by_city['City'].endswith('getxo'),'ESP')
.when(Users_by_city['City'].endswith('toronto/newmarket'),'CAN')
.when(Users_by_city['City'].endswith('king of prussia'),'USA')
.when(Users_by_city['City'].endswith('omaha'),'USA')
.when(Users_by_city['City'].endswith('pepperell'),'USA')
.when(Users_by_city['City'].endswith('sharjah'),'ARE')
.when(Users_by_city['City'].endswith('berkeley'),'USA')
.when(Users_by_city['City'].endswith('weston'),'USA')
.otherwise(Users_by_city['countries_formatted_1']))
.drop(Users_by_city['countries_formatted_1'])

# %%
Users_by_city.show()
# Out:
# +------------+-----+-------------------+---------------------+
# |        City|count|countries_formatted|countries_formatted_1|
# +------------+-----+-------------------+---------------------+
# |     unknown|  100|               null|                 null|
# |     toronto|   59|               null|                  CAN|
# |      milano|   59|                ITA|                  ITA|
# |   vancouver|   58|               null|                  CAN|
# |      london|   51|                GBR|                  GBR|
# |    belgrade|   50|               null|                  SRB|
# |        roma|   48|                ITA|                  ITA|
# |    portland|   45|                JAM|                  JAM|
# |     seattle|   38|               null|                  USA|
# |      ottawa|   37|               null|                  CAN|
# |   barcelona|   33|                ESP|                  ESP|
# |        rome|   32|                CZE|                  ITA|
# |   san diego|   29|               null|                  USA|
# |christchurch|   29|                GBR|                  GBR|
# |     chicago|   27|               null|                  USA|
# |     houston|   27|               null|                  USA|
# | albuquerque|   26|               null|                  USA|
# |      austin|   25|               null|                  USA|
# |      madrid|   25|                ESP|                  ESP|
# |    novi sad|   24|               null|                  SRB|
# +------------+-----+-------------------+---------------------+
# only showing top 20 rows

# %%
#Cleaning table from columns duplicates and join with Country code sort by City
Users_by_city=Users_by_city.withColumnRenamed("City","Distinct_City")
Users_NULL_Countries=USERS_DF.where(col("countries_formatted").isNull())
Users_NULL_Countries=Users_NULL_Countries.drop(Users_NULL_Countries['countries_formatted']) 
Users_NULL_Countries=Users_NULL_Countries.join(Users_by_city, Users_NULL_Countries["City"] == Users_by_city["Distinct_City"],"left")
Users_NULL_Countries=Users_NULL_Countries.drop(Users_NULL_Countries['Distinct_City']) 
Users_NULL_Countries=Users_NULL_Countries.drop(Users_NULL_Countries['count']) 
Users_NULL_Countries.show()

# %%
#Union 2 tables: with Country code sorted by City and with Country code sorted by Country
Users_Countries=USERS_DF.na.drop()
UNION_USERS = Users_Countries.union(Users_NULL_Countries)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-41-18288eab9902> in <module>
#       1 #Union 2 tables: with Country code sorted by City and with Country code sorted by Country
#       2 Users_Countries=USERS_DF.na.drop()
# ----> 3 UNION_USERS = Users_Countries.union(Users_NULL_Countries)
#
# /content/spark-3.2.3-bin-hadoop3.2/python/pyspark/sql/dataframe.py in union(self, other)
#    1842         Also as standard in SQL, this function resolves columns by position (not by name).
#    1843         """
# -> 1844         return DataFrame(self._jdf.union(other._jdf), self.sql_ctx)
#    1845
#    1846     @since(1.3)
#
# spark-3.2.3-bin-hadoop3.2/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# -> 1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#
# /content/spark-3.2.3-bin-hadoop3.2/python/pyspark/sql/utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# AnalysisException: Union can only be performed on tables with the same number of columns, but the first table has 6 columns and the second table has 7 columns;
# 'Union false, false
# :- Filter atleastnnonnulls(6, User-ID#310, Age#538, City#383, State#372, Country#361, countries_formatted#721)
# :  +- Project [User-ID#310, Age#538, City#383, State#372, Country#361, countries_formatted#721]
# :     +- Project [User-ID#310, Age#538, City#383, State#372, Country#361, count#704L, countries_formatted#721]
# :        +- Join LeftOuter, (Country#361 = Distinct_Country#741)
# :           :- Filter atleastnnonnulls(1, User-ID#310)
# :           :  +- Project [User-ID#310, CASE WHEN (Age#477 > 100) THEN -1 WHEN (Age#477 < 7) THEN -1 ELSE Age#477 END AS Age#538, City#383, State#372, Country#361]
# :           :     +- Project [User-ID#310, coalesce(Age#311, cast(-1.0 as int)) AS Age#477, City#383, State#372, Country#361]
# :           :        +- Project [User-ID#310, Age#311, coalesce(City#350, cast(unknown as string)) AS City#383, State#372, Country#361]
# :           :           +- Project [User-ID#310, Age#311, City#350, coalesce(State#338, cast(unknown as string)) AS State#372, Country#361]
# :           :              +- Project [User-ID#310, Age#311, City#350, State#338, coalesce(Country#344, cast(unknown as string)) AS Country#361]
# :           :                 +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#332, n/a) THEN regexp_replace(City#332, n/a, unknown, 1) ELSE City#332 END AS City#350, State#338, Country#344]
# :           :                    +- Project [User-ID#310, Age#311, City#332, State#338, CASE WHEN EndsWith(Country#326, n/a) THEN regexp_replace(Country#326, n/a, unknown, 1) ELSE Country#326 END AS Country#344]
# :           :                       +- Project [User-ID#310, Age#311, City#332, CASE WHEN EndsWith(State#320, n/a) THEN regexp_replace(State#320, n/a, unknown, 1) ELSE State#320 END AS State#338, Country#326]
# :           :                          +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#312,  ) THEN regexp_replace(City#312,  , unknown, 1) ELSE City#312 END AS City#332, State#320, Country#326]
# :           :                             +- Project [User-ID#310, Age#311, City#312, State#320, CASE WHEN EndsWith(Country#314,  ) THEN regexp_replace(Country#314,  , unknown, 1) ELSE Country#314 END AS Country#326]
# :           :                                +- Project [User-ID#310, Age#311, City#312, CASE WHEN EndsWith(State#313,  ) THEN regexp_replace(State#313,  , unknown, 1) ELSE State#313 END AS State#320, Country#314]
# :           :                                   +- Project [CASE WHEN (User-ID#192 = cast( as int)) THEN cast(null as int) ELSE User-ID#192 END AS User-ID#310, CASE WHEN (Age#198 = cast( as int)) THEN cast(null as int) ELSE Age#198 END AS Age#311, CASE WHEN (City#163 = ) THEN cast(null as string) ELSE City#163 END AS City#312, CASE WHEN (State#168 = ) THEN cast(null as string) ELSE State#168 END AS State#313, CASE WHEN (Country#186 = ) THEN cast(null as string) ELSE Country#186 END AS Country#314]
# :           :                                      +- Project [User-ID#192, cast(Age#18 as int) AS Age#198, City#163, State#168, Country#186]
# :           :                                         +- Project [cast(User-ID#16 as int) AS User-ID#192, Age#18, City#163, State#168, Country#186]
# :           :                                            +- Project [User-ID#16, Age#18, City#163, State#168, lower(Country#174) AS Country#186]
# :           :                                               +- Project [User-ID#16, Age#18, City#163, State#168, Country#174]
# :           :                                                  +- Project [User-ID#16, Location#17, Age#18, City#163, State#168, split(Location#17, ,, -1)[2] AS Country#174]
# :           :                                                     +- Project [User-ID#16, Location#17, Age#18, City#163, split(Location#17, ,, -1)[1] AS State#168]
# :           :                                                        +- Project [User-ID#16, Location#17, Age#18, split(Location#17, ,, -1)[0] AS City#163]
# :           :                                                           +- Relation [User-ID#16,Location#17,Age#18] csv
# :           +- Project [Country#361 AS Distinct_Country#741, count#704L, countries_formatted#721]
# :              +- Project [Country#361, count#704L, convert(Country#361) AS countries_formatted#721]
# :                 +- Sort [count#704L DESC NULLS LAST], true
# :                    +- Aggregate [Country#361], [Country#361, count(1) AS count#704L]
# :                       +- Filter atleastnnonnulls(1, User-ID#310)
# :                          +- Project [User-ID#310, CASE WHEN (Age#477 > 100) THEN -1 WHEN (Age#477 < 7) THEN -1 ELSE Age#477 END AS Age#538, City#383, State#372, Country#361]
# :                             +- Project [User-ID#310, coalesce(Age#311, cast(-1.0 as int)) AS Age#477, City#383, State#372, Country#361]
# :                                +- Project [User-ID#310, Age#311, coalesce(City#350, cast(unknown as string)) AS City#383, State#372, Country#361]
# :                                   +- Project [User-ID#310, Age#311, City#350, coalesce(State#338, cast(unknown as string)) AS State#372, Country#361]
# :                                      +- Project [User-ID#310, Age#311, City#350, State#338, coalesce(Country#344, cast(unknown as string)) AS Country#361]
# :                                         +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#332, n/a) THEN regexp_replace(City#332, n/a, unknown, 1) ELSE City#332 END AS City#350, State#338, Country#344]
# :                                            +- Project [User-ID#310, Age#311, City#332, State#338, CASE WHEN EndsWith(Country#326, n/a) THEN regexp_replace(Country#326, n/a, unknown, 1) ELSE Country#326 END AS Country#344]
# :                                               +- Project [User-ID#310, Age#311, City#332, CASE WHEN EndsWith(State#320, n/a) THEN regexp_replace(State#320, n/a, unknown, 1) ELSE State#320 END AS State#338, Country#326]
# :                                                  +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#312,  ) THEN regexp_replace(City#312,  , unknown, 1) ELSE City#312 END AS City#332, State#320, Country#326]
# :                                                     +- Project [User-ID#310, Age#311, City#312, State#320, CASE WHEN EndsWith(Country#314,  ) THEN regexp_replace(Country#314,  , unknown, 1) ELSE Country#314 END AS Country#326]
# :                                                        +- Project [User-ID#310, Age#311, City#312, CASE WHEN EndsWith(State#313,  ) THEN regexp_replace(State#313,  , unknown, 1) ELSE State#313 END AS State#320, Country#314]
# :                                                           +- Project [CASE WHEN (User-ID#192 = cast( as int)) THEN cast(null as int) ELSE User-ID#192 END AS User-ID#310, CASE WHEN (Age#198 = cast( as int)) THEN cast(null as int) ELSE Age#198 END AS Age#311, CASE WHEN (City#163 = ) THEN cast(null as string) ELSE City#163 END AS City#312, CASE WHEN (State#168 = ) THEN cast(null as string) ELSE State#168 END AS State#313, CASE WHEN (Country#186 = ) THEN cast(null as string) ELSE Country#186 END AS Country#314]
# :                                                              +- Project [User-ID#192, cast(Age#763 as int) AS Age#198, City#163, State#168, Country#186]
# :                                                                 +- Project [cast(User-ID#761 as int) AS User-ID#192, Age#763, City#163, State#168, Country#186]
# :                                                                    +- Project [User-ID#761, Age#763, City#163, State#168, lower(Country#174) AS Country#186]
# :                                                                       +- Project [User-ID#761, Age#763, City#163, State#168, Country#174]
# :                                                                          +- Project [User-ID#761, Location#762, Age#763, City#163, State#168, split(Location#762, ,, -1)[2] AS Country#174]
# :                                                                             +- Project [User-ID#761, Location#762, Age#763, City#163, split(Location#762, ,, -1)[1] AS State#168]
# :                                                                                +- Project [User-ID#761, Location#762, Age#763, split(Location#762, ,, -1)[0] AS City#163]
# :                                                                                   +- Relation [User-ID#761,Location#762,Age#763] csv
# +- Project [User-ID#310 AS User-ID#1006, Age#538 AS Age#1007, City#383 AS City#1008, State#372 AS State#1009, Country#361 AS Country#1010, countries_formatted#863 AS countries_formatted#1011, countries_formatted_1#906 AS countries_formatted_1#1012]
#    +- Project [User-ID#310, Age#538, City#383, State#372, Country#361, countries_formatted#863, countries_formatted_1#906]
#       +- Project [User-ID#310, Age#538, City#383, State#372, Country#361, count#843L, countries_formatted#863, countries_formatted_1#906]
#          +- Join LeftOuter, (City#383 = Distinct_City#911)
#             :- Project [User-ID#310, Age#538, City#383, State#372, Country#361]
#             :  +- Filter isnull(countries_formatted#721)
#             :     +- Project [User-ID#310, Age#538, City#383, State#372, Country#361, countries_formatted#721]
#             :        +- Project [User-ID#310, Age#538, City#383, State#372, Country#361, count#704L, countries_formatted#721]
#             :           +- Join LeftOuter, (Country#361 = Distinct_Country#741)
#             :              :- Filter atleastnnonnulls(1, User-ID#310)
#             :              :  +- Project [User-ID#310, CASE WHEN (Age#477 > 100) THEN -1 WHEN (Age#477 < 7) THEN -1 ELSE Age#477 END AS Age#538, City#383, State#372, Country#361]
#             :              :     +- Project [User-ID#310, coalesce(Age#311, cast(-1.0 as int)) AS Age#477, City#383, State#372, Country#361]
#             :              :        +- Project [User-ID#310, Age#311, coalesce(City#350, cast(unknown as string)) AS City#383, State#372, Country#361]
#             :              :           +- Project [User-ID#310, Age#311, City#350, coalesce(State#338, cast(unknown as string)) AS State#372, Country#361]
#             :              :              +- Project [User-ID#310, Age#311, City#350, State#338, coalesce(Country#344, cast(unknown as string)) AS Country#361]
#             :              :                 +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#332, n/a) THEN regexp_replace(City#332, n/a, unknown, 1) ELSE City#332 END AS City#350, State#338, Country#344]
#             :              :                    +- Project [User-ID#310, Age#311, City#332, State#338, CASE WHEN EndsWith(Country#326, n/a) THEN regexp_replace(Country#326, n/a, unknown, 1) ELSE Country#326 END AS Country#344]
#             :              :                       +- Project [User-ID#310, Age#311, City#332, CASE WHEN EndsWith(State#320, n/a) THEN regexp_replace(State#320, n/a, unknown, 1) ELSE State#320 END AS State#338, Country#326]
#             :              :                          +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#312,  ) THEN regexp_replace(City#312,  , unknown, 1) ELSE City#312 END AS City#332, State#320, Country#326]
#             :              :                             +- Project [User-ID#310, Age#311, City#312, State#320, CASE WHEN EndsWith(Country#314,  ) THEN regexp_replace(Country#314,  , unknown, 1) ELSE Country#314 END AS Country#326]
#             :              :                                +- Project [User-ID#310, Age#311, City#312, CASE WHEN EndsWith(State#313,  ) THEN regexp_replace(State#313,  , unknown, 1) ELSE State#313 END AS State#320, Country#314]
#             :              :                                   +- Project [CASE WHEN (User-ID#192 = cast( as int)) THEN cast(null as int) ELSE User-ID#192 END AS User-ID#310, CASE WHEN (Age#198 = cast( as int)) THEN cast(null as int) ELSE Age#198 END AS Age#311, CASE WHEN (City#163 = ) THEN cast(null as string) ELSE City#163 END AS City#312, CASE WHEN (State#168 = ) THEN cast(null as string) ELSE State#168 END AS State#313, CASE WHEN (Country#186 = ) THEN cast(null as string) ELSE Country#186 END AS Country#314]
#             :              :                                      +- Project [User-ID#192, cast(Age#1002 as int) AS Age#198, City#163, State#168, Country#186]
#             :              :                                         +- Project [cast(User-ID#1000 as int) AS User-ID#192, Age#1002, City#163, State#168, Country#186]
#             :              :                                            +- Project [User-ID#1000, Age#1002, City#163, State#168, lower(Country#174) AS Country#186]
#             :              :                                               +- Project [User-ID#1000, Age#1002, City#163, State#168, Country#174]
#             :              :                                                  +- Project [User-ID#1000, Location#1001, Age#1002, City#163, State#168, split(Location#1001, ,, -1)[2] AS Country#174]
#             :              :                                                     +- Project [User-ID#1000, Location#1001, Age#1002, City#163, split(Location#1001, ,, -1)[1] AS State#168]
#             :              :                                                        +- Project [User-ID#1000, Location#1001, Age#1002, split(Location#1001, ,, -1)[0] AS City#163]
#             :              :                                                           +- Relation [User-ID#1000,Location#1001,Age#1002] csv
#             :              +- Project [Country#361 AS Distinct_Country#741, count#704L, countries_formatted#721]
#             :                 +- Project [Country#361, count#704L, convert(Country#361) AS countries_formatted#721]
#             :                    +- Sort [count#704L DESC NULLS LAST], true
#             :                       +- Aggregate [Country#361], [Country#361, count(1) AS count#704L]
#             :                          +- Filter atleastnnonnulls(1, User-ID#310)
#             :                             +- Project [User-ID#310, CASE WHEN (Age#477 > 100) THEN -1 WHEN (Age#477 < 7) THEN -1 ELSE Age#477 END AS Age#538, City#383, State#372, Country#361]
#             :                                +- Project [User-ID#310, coalesce(Age#311, cast(-1.0 as int)) AS Age#477, City#383, State#372, Country#361]
#             :                                   +- Project [User-ID#310, Age#311, coalesce(City#350, cast(unknown as string)) AS City#383, State#372, Country#361]
#             :                                      +- Project [User-ID#310, Age#311, City#350, coalesce(State#338, cast(unknown as string)) AS State#372, Country#361]
#             :                                         +- Project [User-ID#310, Age#311, City#350, State#338, coalesce(Country#344, cast(unknown as string)) AS Country#361]
#             :                                            +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#332, n/a) THEN regexp_replace(City#332, n/a, unknown, 1) ELSE City#332 END AS City#350, State#338, Country#344]
#             :                                               +- Project [User-ID#310, Age#311, City#332, State#338, CASE WHEN EndsWith(Country#326, n/a) THEN regexp_replace(Country#326, n/a, unknown, 1) ELSE Country#326 END AS Country#344]
#             :                                                  +- Project [User-ID#310, Age#311, City#332, CASE WHEN EndsWith(State#320, n/a) THEN regexp_replace(State#320, n/a, unknown, 1) ELSE State#320 END AS State#338, Country#326]
#             :                                                     +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#312,  ) THEN regexp_replace(City#312,  , unknown, 1) ELSE City#312 END AS City#332, State#320, Country#326]
#             :                                                        +- Project [User-ID#310, Age#311, City#312, State#320, CASE WHEN EndsWith(Country#314,  ) THEN regexp_replace(Country#314,  , unknown, 1) ELSE Country#314 END AS Country#326]
#             :                                                           +- Project [User-ID#310, Age#311, City#312, CASE WHEN EndsWith(State#313,  ) THEN regexp_replace(State#313,  , unknown, 1) ELSE State#313 END AS State#320, Country#314]
#             :                                                              +- Project [CASE WHEN (User-ID#192 = cast( as int)) THEN cast(null as int) ELSE User-ID#192 END AS User-ID#310, CASE WHEN (Age#198 = cast( as int)) THEN cast(null as int) ELSE Age#198 END AS Age#311, CASE WHEN (City#163 = ) THEN cast(null as string) ELSE City#163 END AS City#312, CASE WHEN (State#168 = ) THEN cast(null as string) ELSE State#168 END AS State#313, CASE WHEN (Country#186 = ) THEN cast(null as string) ELSE Country#186 END AS Country#314]
#             :                                                                 +- Project [User-ID#192, cast(Age#1005 as int) AS Age#198, City#163, State#168, Country#186]
#             :                                                                    +- Project [cast(User-ID#1003 as int) AS User-ID#192, Age#1005, City#163, State#168, Country#186]
#             :                                                                       +- Project [User-ID#1003, Age#1005, City#163, State#168, lower(Country#174) AS Country#186]
#             :                                                                          +- Project [User-ID#1003, Age#1005, City#163, State#168, Country#174]
#             :                                                                             +- Project [User-ID#1003, Location#1004, Age#1005, City#163, State#168, split(Location#1004, ,, -1)[2] AS Country#174]
#             :                                                                                +- Project [User-ID#1003, Location#1004, Age#1005, City#163, split(Location#1004, ,, -1)[1] AS State#168]
#             :                                                                                   +- Project [User-ID#1003, Location#1004, Age#1005, split(Location#1004, ,, -1)[0] AS City#163]
#             :                                                                                      +- Relation [User-ID#1003,Location#1004,Age#1005] csv
#             +- Project [City#383 AS Distinct_City#911, count#843L, countries_formatted#863, countries_formatted_1#906]
#                +- Project [City#383, count#843L, countries_formatted#863, CASE WHEN EndsWith(City#383, toronto) THEN CAN WHEN EndsWith(City#383, vancouver) THEN CAN WHEN EndsWith(City#383, ottawa) THEN CAN WHEN EndsWith(City#383, belgrade) THEN SRB WHEN EndsWith(City#383, seattle) THEN USA WHEN EndsWith(City#383, rome) THEN ITA WHEN EndsWith(City#383, san diego) THEN USA WHEN EndsWith(City#383, chicago) THEN USA WHEN EndsWith(City#383, houston) THEN USA WHEN EndsWith(City#383, albuquerque) THEN USA WHEN EndsWith(City#383, austin) THEN USA WHEN EndsWith(City#383, novi sad) THEN SRB WHEN EndsWith(City#383, calgary) THEN CAN WHEN EndsWith(City#383, los angeles) THEN USA WHEN EndsWith(City#383, sydney) THEN AUS WHEN EndsWith(City#383, melbourne) THEN AUS WHEN EndsWith(City#383, cincinnati) THEN USA WHEN EndsWith(City#383, stuttgart) THEN DEU WHEN EndsWith(City#383, san francisco) THEN USA WHEN EndsWith(City#383, st. louis) THEN USA WHEN EndsWith(City#383, fredericton) THEN CAN WHEN EndsWith(City#383, raleigh) THEN USA WHEN EndsWith(City#383, oakland) THEN USA WHEN EndsWith(City#383, winnipeg) THEN CAN WHEN EndsWith(City#383, edmonton) THEN CAN WHEN EndsWith(City#383, tucson) THEN USA WHEN EndsWith(City#383, cairo) THEN EGY WHEN EndsWith(City#383, newark) THEN USA WHEN EndsWith(City#383, amsterdam) THEN NLD WHEN EndsWith(City#383, dubai) THEN ARE WHEN EndsWith(City#383, minneapolis) THEN USA WHEN EndsWith(City#383, copenhagen) THEN DNA WHEN EndsWith(City#383, hamilton) THEN CAN...
#                   +- Project [City#383, count#843L, convert(City#383) AS countries_formatted#863]
#                      +- Sort [count#843L DESC NULLS LAST], true
#                         +- Aggregate [City#383], [City#383, count(1) AS count#843L]
#                            +- Project [User-ID#310, Age#538, City#383, State#372, Country#361]
#                               +- Filter isnull(countries_formatted#721)
#                                  +- Project [User-ID#310, Age#538, City#383, State#372, Country#361, countries_formatted#721]
#                                     +- Project [User-ID#310, Age#538, City#383, State#372, Country#361, count#704L, countries_formatted#721]
#                                        +- Join LeftOuter, (Country#361 = Distinct_Country#741)
#                                           :- Filter atleastnnonnulls(1, User-ID#310)
#                                           :  +- Project [User-ID#310, CASE WHEN (Age#477 > 100) THEN -1 WHEN (Age#477 < 7) THEN -1 ELSE Age#477 END AS Age#538, City#383, State#372, Country#361]
#                                           :     +- Project [User-ID#310, coalesce(Age#311, cast(-1.0 as int)) AS Age#477, City#383, State#372, Country#361]
#                                           :        +- Project [User-ID#310, Age#311, coalesce(City#350, cast(unknown as string)) AS City#383, State#372, Country#361]
#                                           :           +- Project [User-ID#310, Age#311, City#350, coalesce(State#338, cast(unknown as string)) AS State#372, Country#361]
#                                           :              +- Project [User-ID#310, Age#311, City#350, State#338, coalesce(Country#344, cast(unknown as string)) AS Country#361]
#                                           :                 +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#332, n/a) THEN regexp_replace(City#332, n/a, unknown, 1) ELSE City#332 END AS City#350, State#338, Country#344]
#                                           :                    +- Project [User-ID#310, Age#311, City#332, State#338, CASE WHEN EndsWith(Country#326, n/a) THEN regexp_replace(Country#326, n/a, unknown, 1) ELSE Country#326 END AS Country#344]
#                                           :                       +- Project [User-ID#310, Age#311, City#332, CASE WHEN EndsWith(State#320, n/a) THEN regexp_replace(State#320, n/a, unknown, 1) ELSE State#320 END AS State#338, Country#326]
#                                           :                          +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#312,  ) THEN regexp_replace(City#312,  , unknown, 1) ELSE City#312 END AS City#332, State#320, Country#326]
#                                           :                             +- Project [User-ID#310, Age#311, City#312, State#320, CASE WHEN EndsWith(Country#314,  ) THEN regexp_replace(Country#314,  , unknown, 1) ELSE Country#314 END AS Country#326]
#                                           :                                +- Project [User-ID#310, Age#311, City#312, CASE WHEN EndsWith(State#313,  ) THEN regexp_replace(State#313,  , unknown, 1) ELSE State#313 END AS State#320, Country#314]
#                                           :                                   +- Project [CASE WHEN (User-ID#192 = cast( as int)) THEN cast(null as int) ELSE User-ID#192 END AS User-ID#310, CASE WHEN (Age#198 = cast( as int)) THEN cast(null as int) ELSE Age#198 END AS Age#311, CASE WHEN (City#163 = ) THEN cast(null as string) ELSE City#163 END AS City#312, CASE WHEN (State#168 = ) THEN cast(null as string) ELSE State#168 END AS State#313, CASE WHEN (Country#186 = ) THEN cast(null as string) ELSE Country#186 END AS Country#314]
#                                           :                                      +- Project [User-ID#192, cast(Age#923 as int) AS Age#198, City#163, State#168, Country#186]
#                                           :                                         +- Project [cast(User-ID#921 as int) AS User-ID#192, Age#923, City#163, State#168, Country#186]
#                                           :                                            +- Project [User-ID#921, Age#923, City#163, State#168, lower(Country#174) AS Country#186]
#                                           :                                               +- Project [User-ID#921, Age#923, City#163, State#168, Country#174]
#                                           :                                                  +- Project [User-ID#921, Location#922, Age#923, City#163, State#168, split(Location#922, ,, -1)[2] AS Country#174]
#                                           :                                                     +- Project [User-ID#921, Location#922, Age#923, City#163, split(Location#922, ,, -1)[1] AS State#168]
#                                           :                                                        +- Project [User-ID#921, Location#922, Age#923, split(Location#922, ,, -1)[0] AS City#163]
#                                           :                                                           +- Relation [User-ID#921,Location#922,Age#923] csv
#                                           +- Project [Country#361 AS Distinct_Country#741, count#704L, countries_formatted#721]
#                                              +- Project [Country#361, count#704L, convert(Country#361) AS countries_formatted#721]
#                                                 +- Sort [count#704L DESC NULLS LAST], true
#                                                    +- Aggregate [Country#361], [Country#361, count(1) AS count#704L]
#                                                       +- Filter atleastnnonnulls(1, User-ID#310)
#                                                          +- Project [User-ID#310, CASE WHEN (Age#477 > 100) THEN -1 WHEN (Age#477 < 7) THEN -1 ELSE Age#477 END AS Age#538, City#383, State#372, Country#361]
#                                                             +- Project [User-ID#310, coalesce(Age#311, cast(-1.0 as int)) AS Age#477, City#383, State#372, Country#361]
#                                                                +- Project [User-ID#310, Age#311, coalesce(City#350, cast(unknown as string)) AS City#383, State#372, Country#361]
#                                                                   +- Project [User-ID#310, Age#311, City#350, coalesce(State#338, cast(unknown as string)) AS State#372, Country#361]
#                                                                      +- Project [User-ID#310, Age#311, City#350, State#338, coalesce(Country#344, cast(unknown as string)) AS Country#361]
#                                                                         +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#332, n/a) THEN regexp_replace(City#332, n/a, unknown, 1) ELSE City#332 END AS City#350, State#338, Country#344]
#                                                                            +- Project [User-ID#310, Age#311, City#332, State#338, CASE WHEN EndsWith(Country#326, n/a) THEN regexp_replace(Country#326, n/a, unknown, 1) ELSE Country#326 END AS Country#344]
#                                                                               +- Project [User-ID#310, Age#311, City#332, CASE WHEN EndsWith(State#320, n/a) THEN regexp_replace(State#320, n/a, unknown, 1) ELSE State#320 END AS State#338, Country#326]
#                                                                                  +- Project [User-ID#310, Age#311, CASE WHEN EndsWith(City#312,  ) THEN regexp_replace(City#312,  , unknown, 1) ELSE City#312 END AS City#332, State#320, Country#326]
#                                                                                     +- Project [User-ID#310, Age#311, City#312, State#320, CASE WHEN EndsWith(Country#314,  ) THEN regexp_replace(Country#314,  , unknown, 1) ELSE Country#314 END AS Country#326]
#                                                                                        +- Project [User-ID#310, Age#311, City#312, CASE WHEN EndsWith(State#313,  ) THEN regexp_replace(State#313,  , unknown, 1) ELSE State#313 END AS State#320, Country#314]
#                                                                                           +- Project [CASE WHEN (User-ID#192 = cast( as int)) THEN cast(null as int) ELSE User-ID#192 END AS User-ID#310, CASE WHEN (Age#198 = cast( as int)) THEN cast(null as int) ELSE Age#198 END AS Age#311, CASE WHEN (City#163 = ) THEN cast(null as string) ELSE City#163 END AS City#312, CASE WHEN (State#168 = ) THEN cast(null as string) ELSE State#168 END AS State#313, CASE WHEN (Country#186 = ) THEN cast(null as string) ELSE Country#186 END AS Country#314]
#                                                                                              +- Project [User-ID#192, cast(Age#926 as int) AS Age#198, City#163, State#168, Country#186]
#                                                                                                 +- Project [cast(User-ID#924 as int) AS User-ID#192, Age#926, City#163, State#168, Country#186]
#                                                                                                    +- Project [User-ID#924, Age#926, City#163, State#168, lower(Country#174) AS Country#186]
#                                                                                                       +- Project [User-ID#924, Age#926, City#163, State#168, Country#174]
#                                                                                                          +- Project [User-ID#924, Location#925, Age#926, City#163, State#168, split(Location#925, ,, -1)[2] AS Country#174]
#                                                                                                             +- Project [User-ID#924, Location#925, Age#926, City#163, split(Location#925, ,, -1)[1] AS State#168]
#                                                                                                                +- Project [User-ID#924, Location#925, Age#926, split(Location#925, ,, -1)[0] AS City#163]
#                                                                                                                   +- Relation [User-ID#924,Location#925,Age#926] csv

# %%
#Save file in csv
UNION_USERS.coalesce(1).write.option('header', 'True').csv("/content/drive/MyDrive/BDA Technion/Big Data Project/Users")

# %%
#Chech how many null value we still have
UNION_USERS.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in UNION_USERS.columns]).show()
# Out:
# +-------+---+----+-----+-------+-------------------+
# |User-ID|Age|City|State|Country|countries_formatted|
# +-------+---+----+-----+-------+-------------------+
# |      0|  0|   0|    0|      0|               4451|
# +-------+---+----+-----+-------+-------------------+

# %%
#Check that we don't loose any row
UNION_USERS.count()
# Out:
# 278858

# %% [markdown]
# # Stop Session

# %%
# Stop the session --> similar to saving our doings in spark layer
spark.stop()
